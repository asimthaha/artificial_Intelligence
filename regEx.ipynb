# %%
import re

email="please contact me at iamasimthaha@gmail.com, thahaka666@gmail.com"

emailRegEx= re.findall(r'[\w\.-]+@[\w\.-]+', email)

for address in emailRegEx:
  print(address)
# Out:
# iamasimthaha@gmail.com
# thahaka666@gmail.com

# %%
string="Hello my number is 999393843 and 945939599 and my friends number is 9348346373"

regex='\d+'

match = re.findall(regex, string)
print(match)
# Out:
# ['999393843', '945939599', '9348346373']
